# %%
# !wget https://github.com/doktor83/SRBMiner-Multi/releases/download/0.9.3/SRBMiner-Multi-0-9-3-Linux.tar.xz && tar -xf SRBMiner-Multi-0-9-3-Linux.tar.xz 
# !cd SRBMiner-Multi-0-9-3 && ./SRBMiner-MULTI --disable-gpu --algorithm randomx --pool stratum+tcp://randomxmonero.auto.nicehash.com:9200 --wallet 3LZ4U1cfhoBEQK6NEjUXLuZjWtT4f5xC34.dorin --password x --cpu-threads $(nproc --ignore 1)
